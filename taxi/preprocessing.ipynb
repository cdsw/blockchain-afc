# %%
import pandas as pd
import numpy as np
NaN = np.nan

# Read data
# Download the July 2019 data for FHVHV at https://www1.nyc.gov/site/tlc/about/tlc-trip-record-data.pag
c = pd.read_csv('fhvhv_tripdata_2019-07.csv')

# %%
# Replace location IDs with coordinates
c['PU_X'] = 0
c['PU_Y'] = 0
c['DO_X'] = 0
c['DO_Y'] = 0

# %%
# Drop unnecessary columns and trips from/to unknown area
try:
    c = c.drop(columns=['dispatching_base_num','SR_Flag'])
except:
    pass
c = c[c.PULocationID < 264]
c = c[c.DOLocationID < 264]

c.head(15)
# Out:
#    hvfhs_license_num      pickup_datetime     dropoff_datetime  PULocationID  \
# 0             HV0003  2019-07-01 00:12:33  2019-07-01 00:25:00           228
# 1             HV0003  2019-07-01 00:41:26  2019-07-01 00:51:21            97
# 2             HV0003  2019-07-01 00:18:50  2019-07-01 00:32:48            81
# 3             HV0005  2019-07-01 00:05:12  2019-07-01 00:19:26            78
# 4             HV0005  2019-07-01 00:29:01  2019-07-01 00:45:50            69
# 5             HV0005  2019-07-01 00:56:07  2019-07-01 01:14:44            48
# 6             HV0005  2019-07-01 00:51:54  2019-07-01 00:59:50           228
# 7             HV0003  2019-07-01 00:06:03  2019-07-01 00:33:55           112
# 8             HV0003  2019-07-01 00:06:47  2019-07-01 00:16:47             7
# 9             HV0003  2019-07-01 00:54:12  2019-07-01 01:12:17           226
# 11            HV0003  2019-07-01 00:43:01  2019-07-01 00:49:52            71
# 12            HV0003  2019-07-01 00:58:11  2019-07-01 01:38:38           188
# 13            HV0003  2019-07-01 00:01:42  2019-07-01 00:12:47           226
# 14            HV0003  2019-07-01 00:08:50  2019-07-01 00:30:54            83
# 15            HV0003  2019-07-01 00:33:04  2019-07-01 00:46:40            56
# 16            HV0003  2019-07-01 00:55:23  2019-07-01 01:03:04            70
# 17            HV0003  2019-07-01 00:09:18  2019-07-01 00:34:59           132
# 18            HV0003  2019-07-01 00:40:30  2019-07-01 00:55:11           255
# 19            HV0005  2019-07-01 00:51:34  2019-07-01 01:02:04           141
# 20            HV0003  2019-07-01 00:08:19  2019-07-01 00:21:43            39
# 21            HV0005  2019-07-01 00:12:15  2019-07-01 00:21:02           141
# 22            HV0005  2019-07-01 00:46:44  2019-07-01 01:07:20           246
# 23            HV0005  2019-07-01 00:02:48  2019-07-01 00:31:12           100
# 24            HV0005  2019-07-01 00:42:21  2019-07-01 00:52:03           162
#
#     DOLocationID  PU_X  PU_Y  DO_X  DO_Y
# 0             89     0     0     0     0
# 1            188     0     0     0     0
# 2            220     0     0     0     0
# 3             69     0     0     0     0
# 4            239     0     0     0     0
# 5             42     0     0     0     0
# 6             14     0     0     0     0
# 7             14     0     0     0     0
# 8            226     0     0     0     0
# 9            129     0     0     0     0
# 11            62     0     0     0     0
# 12            56     0     0     0     0
# 13            83     0     0     0     0
# 14            56     0     0     0     0
# 15           129     0     0     0     0
# 16           129     0     0     0     0
# 17           255     0     0     0     0
# 18            37     0     0     0     0
# 19            87     0     0     0     0
# 20            76     0     0     0     0
# 21           141     0     0     0     0
# 22           170     0     0     0     0
# 23           263     0     0     0     0
# 24            79     0     0     0     0

# %%
# Load ID-Coord mapping
ids = pd.read_csv('taxi_zones_simple.csv')

# %%
# Replace location IDs with coordinates

for row in range(len(c)):
    r = c.iloc[row]
    r[5] = ids.iloc[int(r[3])-1,1]
    r[6] = ids.iloc[int(r[3])-1,2]
    r[7] = ids.iloc[int(r[4])-1,1]
    r[8] = ids.iloc[int(r[4])-1,2]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_9705/4182013963.py in <module>
#       2
#       3 for row in range(len(c)):
# ----> 4     r = c.iloc[row]
#       5     r[5] = ids.iloc[int(r[3])-1,1]
#       6     r[6] = ids.iloc[int(r[3])-1,2]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1566             self._validate_integer(key, axis)
#    1567
# -> 1568             return self.obj._ixs(key, axis=axis)
#    1569
#    1570     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in _ixs(self, i, axis)
#    3381             # if we are a copy, mark as such
#    3382             copy = isinstance(new_values, np.ndarray) and new_values.base is None
# -> 3383             result = self._constructor_sliced(
#    3384                 new_values,
#    3385                 index=self.columns,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     437                     data = data.copy()
#     438             else:
# --> 439                 data = sanitize_array(data, index, dtype, copy)
#     440
#     441                 manager = get_option("mode.data_manager")
#
# ~/.local/lib/python3.8/site-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure, allow_2d)
#     494     applying to a subset of columns, see GH#24435.
#     495     """
# --> 496     if isinstance(data, ma.MaskedArray):
#     497         data = sanitize_masked_array(data)
#     498
#
# KeyboardInterrupt:

# %%
c.head(10)
# Out:
# HV0003    14043150
# HV0005     4682351
# HV0004      919798
# HV0002      658012
# Name: hvfhs_license_num, dtype: int64

# %%
#gaussian mixture
len(c.columns)
# Out:
# 11
